# %% [markdown]
# # Preamble

# %%
from pathlib import Path
import shutil
import json
import pandas as pd
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

from fastai.dataset import *
from fastai.conv_learner import ConvLearner

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
#PATH = Path('D:/msc/kaggle_data/whales')
#IMG_PATH = 'train/new_whale'
PATH = Path('../../kaggle/whales')
IMG_PATH = PATH/'all_images'

# %% [markdown]
# # Get dataset to reasonable form

# %%
train = json.load((PATH/'some_whales_in_boxes.json').open())
train_df = pd.DataFrame(train)
train_df = train_df[['External ID', 'Label']]
train_df = train_df[train_df['Label'] != 'Skip']
train_df['Box'] = train_df.apply( lambda x: x['Label']['Tail'][0], axis=1)

# %%
def init2bb(l):
    return([min(l[0]['y'], l[1]['y'], l[2]['y'], l[3]['y']),
     min(l[0]['x'], l[1]['x'], l[2]['x'], l[3]['x']),
     max(l[0]['y'], l[1]['y'], l[2]['y'], l[3]['y']),
     max(l[0]['x'], l[1]['x'], l[2]['x'], l[3]['x'])])

# %%
train_df['BB'] = train_df.apply( lambda x: init2bb(x['Box']), axis=1)

# %% [markdown]
# # Rewrite the fastai display functions and check that boxes make sense

# %%
def show_img(im, figsize = None, ax = None):
    if not ax: fig, ax = plt.subplots(figsize = figsize)
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    return ax

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(linewidth=lw,foreground='black'), patheffects.Normal()])

# %%
def draw_rect(ax, b):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white',lw=2))
    draw_outline(patch,4)

# %%
def bb_hw(a): return np.array([a[1],a[0],a[3]-a[1]+1,a[2]-a[0]+1])

# %%
def draw_idx(i):
    ax = show_img(open_image(IMG_PATH/train_df.iloc[i]['External ID']))
    b = bb_hw(train_df.iloc[i]['BB'])
    draw_rect(ax, b)

# %% [markdown]
# # Train a resnet of some sort

# %% [markdown]
# ## Make csv

# %% [markdown]
# ### Mine

# %%
csv_df = train_df[['External ID']]

# %%
csv_df.columns = ['fn']

# %%
csv_df['bbox'] = train_df['BB'].apply(lambda x: ' '.join(str(p) for p in x))
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
csv_df.head()
# Out:
#              fn            bbox
# 0  00ad9219.jpg  12 10 279 1044
# 1  3b339885.jpg  66 13 498 1034
# 2  00ded600.jpg   4 14 472 1029
# 3  06e622e0.jpg   14 10 262 880
# 4  3bf857ac.jpg   13 2 420 1044

# %% [markdown]
# ### Lisa's

# %%
lisa_df = pd.read_csv(PATH/'bb_labels_lisa.csv')
lisa_df['BB'] = lisa_df.apply(lambda x: [x['ymin'], x['xmin'], x['ymax'], x['xmax']], axis=1)
lisa_df = lisa_df[['image', 'BB']]
lisa_df.columns = ['fn', 'bbox']
lisa_df.head()

# %%
def draw_idx_lisa(i):
    ax = show_img(open_image(IMG_PATH/lisa_df.iloc[i]['fn']))
    b = bb_hw(lisa_df.iloc[i]['bbox'])
    draw_rect(ax, b)

# %%
draw_idx_lisa(13)

# %% [markdown]
# ### bbrandt's

# %%
bbrandt_df = pd.read_csv(PATH/'bb_kaggle_bbrandt.csv')
bbrandt_df['BB'] = bbrandt_df.apply(lambda x: list(map(int, x['ystart xstart yend xend'].split(' '))), axis=1)
bbrandt_df = bbrandt_df[['fn', 'BB']]
bbrandt_df.columns = ['fn', 'bbox']
bbrandt_df.head()

# %%
def draw_idx_bbrandt(i):
    ax = show_img(open_image(IMG_PATH/bbrandt_df.iloc[i]['fn']))
    b = bb_hw(bbrandt_df.iloc[i]['bbox'])
    draw_rect(ax, b)

# %%
draw_idx_bbrandt(120)

# %% [markdown]
# ### Combine

# %%
lisa_df['bbox'] = lisa_df['bbox'].apply(lambda x: ' '.join(str(p) for p in x))
bbrandt_df['bbox'] = bbrandt_df['bbox'].apply(lambda x: ' '.join(str(p) for p in x))

# %%
csv_df.head(2)
# Out:
#              fn            bbox
# 0  00ad9219.jpg  12 10 279 1044
# 1  3b339885.jpg  66 13 498 1034

# %%
lisa_df.head(2)
# Out:
#              fn             bbox
# 0  00022e1a.jpg      9 9 325 621
# 1  000466c4.jpg  293 227 445 590

# %%
bbrandt_df.head(2)
# Out:
#              fn            bbox
# 0  097f138b.jpg   20 3 423 1042
# 1  c85f1d58.jpg  14 25 547 1009

# %%
csv_df = csv_df.append(lisa_df, ignore_index=True).append(bbrandt_df, ignore_index=True)

# %%
len(np.unique(csv_df['fn'].values))
# Out:
# 1516

# %%
len(csv_df)
# Out:
# 1806

# %%
csv_df.to_csv(PATH/'tmp/bb.csv', index=False)

# %% [markdown]
# ## Train a net

# %%
f_model=resnext50
sz=299
bs=50

# %%
tfm_y = TfmType.COORD
augs = [RandomFlip(tfm_y=tfm_y),
        #RandomRotate(3, p=0.5, tfm_y=tfm_y),
        RandomLighting(0.1,0.1, tfm_y=tfm_y)]
tfms = tfms_from_model(f_model, sz, crop_type=CropType.NO, tfm_y=tfm_y, aug_tfms=augs)
md = ImageClassifierData.from_csv(PATH, 'all_images', PATH/'tmp/bb.csv', tfms = tfms, continuous = True, bs=bs)

# %%
head_reg4 = nn.Sequential(Flatten())
learn = ConvLearner.pretrained(f_model, md, custom_head=head_reg4)
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 299, 299]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-138',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-139',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-141',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-142',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-144',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-145',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-146',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-147',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-148',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-150',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-151',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-153',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-154',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-155',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-156',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Flatten-157',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 204800]),
#                            ('nb_params', 0)]))])

# %%
head_reg4 = nn.Sequential(Flatten(), nn.Linear(204800,4))
learn = ConvLearner.pretrained(f_model, md, custom_head=head_reg4)
learn.opt_fn = optim.Adam
learn.crit = nn.L1Loss()

# %%
learn.lr_find(start_lr=1e-06, end_lr=1e-1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      175.642982 600.468111

# %%
learn.sched.plot()

# %%
lr = 1e-3

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      52.64727   28.157709
#     1      36.509023  17.699945
#     2      25.036312  15.904091
#     3      20.037222  15.422874
#     4      16.406899  13.879697
#     5      13.952226  13.177211
#     6      12.298208  12.965902
# [array([12.9659])]

# %%
lrs = np.array([lr/4,lr/2,lr])

# %%
learn.freeze_to(-2)

# %%
learn.fit(lrs, 5, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=31), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      25.298886  17.081318
#     1      21.337931  16.72266
#     2      16.092458  11.473316
#     3      17.203972  21.093801
#     4      15.111861  12.411874
#     5      12.388886  9.95347
#     6      10.499896  9.018297
#     7      11.020196  12.489063
#     8      11.179279  12.422147
#     9      10.527141  10.290671
#     10     9.319744   9.971064
#     11     8.509224   10.94573
#     12     7.477075   9.318865
#     13     6.637938   8.689576
#     14     5.661031   8.599546
#     15     7.110781   10.007298
#     16     8.513299   10.18242
#     17     8.299937   9.661034
#     18     8.210185   10.641116
#     19     7.956219   9.859397
#     20     7.314446   8.658721
#     21     6.885145   10.043972
#     22     6.35983    7.98144
#     23     5.561788   8.090055
#     24     5.361723   9.397641
#     25     5.0452     7.956725
#     26     4.445572   7.687171
#     27     3.839455   7.443154
#     28     3.387917   7.408189
#     29     3.074159   7.29509
#     30     2.826562   7.279505
# [array([7.27951])]

# %%
#learn.save('reg4_resnext')
learn.load('reg4_resnext')

# %%
it = iter(md.val_dl)

# %%
x,y = next(it)
learn.model.eval()
preds_1 = to_np(learn.model(VV(x)))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-55-a9e59ba7efb8> in <module>()
# ----> 1 x,y = next(it)
#       2 learn.model.eval()
#       3 preds_1 = to_np(learn.model(VV(x)))
#
# StopIteration:

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 8))
for i,ax in enumerate(axes.flat):
    ima=md.val_ds.denorm(to_np(x))[i]
    b = bb_hw(preds_1[i])
    #ax = show_img(ima[int(preds_1[i][0]):int(preds_1[i][2]), int(preds_1[i][1]):int(preds_1[i][3])], ax=ax)
    ax = show_img(ima, ax=ax)
    draw_rect(ax, b)
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Crop the images

# %% [markdown]
# ## Get all train images into same folder (same for validation)

# %%
FULL_TRAIN =  PATH/'train_full'
#FULL_TRAIN.mkdir()
for dr in (PATH/'train').iterdir():
    for file in dr.iterdir():
        shutil.copy(str(file), str(FULL_TRAIN))

# %%
FULL_VALID =  PATH/'validation_full'
#FULL_VALID.mkdir()
for dr in (PATH/'validation').iterdir():
    for file in dr.iterdir():
        shutil.copy(str(file), str(FULL_VALID))

# %% [markdown]
# ## Make a ConvLearner for each case with weights from above and respective test set

# %%
train_data = ImageClassifierData.from_csv(PATH, IMG_PATH, PATH/'tmp/bb.csv', tfms=tfms, continuous = True, test_name='train_full')
train_cropper = ConvLearner.pretrained(f_model, train_data, custom_head=head_reg4)
train_cropper.load('reg4')
train_boxs = train_cropper.predict(is_test=True)

# %%
train_boxs = np.clip(train_boxs,0,sz)

# %%
validation_data = ImageClassifierData.from_csv(PATH, IMG_PATH, PATH/'tmp/bb.csv', tfms=tfms, continuous = True, test_name='validation_full')
validation_cropper = ConvLearner.pretrained(f_model, validation_data, custom_head=head_reg4)
validation_cropper.load('reg4')
validation_boxs = validation_cropper.predict(is_test=True)

# %%
validation_boxs = np.clip(validation_boxs,0,sz)

# %%
test_data = ImageClassifierData.from_csv(PATH, IMG_PATH, PATH/'tmp/bb.csv', tfms=tfms, continuous = True, test_name='test')
test_cropper = ConvLearner.pretrained(f_model, test_data, custom_head=head_reg4)
test_cropper.load('reg4')
test_boxs = test_cropper.predict(is_test=True)

# %%
test_boxs = np.clip(test_boxs,0,sz)

# %% [markdown]
# ## Save results to new folders

# %%
TRAIN_CROPPED_PATH = PATH/'train_cropperd'
#TRAIN_CROPPED_PATH.mkdir()
for dr in (PATH/'train').iterdir():
    #(TRAIN_CROPPED_PATH/dr.name).mkdir()
    for file in dr.iterdir():
        fn='train_full\\'+file.name
        ima = open_image(PATH/fn)
        shape = ima.shape
        idx = np.where(np.array(train_data.test_ds.fnames) == fn)[0][0]
        pred = train_boxs[idx]
        cropped_ima = ima[int(shape[0]*pred[0]/sz):int(shape[0]*pred[2]/sz), int(shape[1]*pred[1]/sz):int(shape[1]*pred[3]/sz)]
        cv2.imwrite(str(TRAIN_CROPPED_PATH/dr.name/file.name), cv2.cvtColor((cropped_ima*255).astype(np.uint8), cv2.COLOR_RGB2BGR))

# %%
VAL_CROPPED_PATH = PATH/'validation_cropperd'
VAL_CROPPED_PATH.mkdir()
for dr in (PATH/'validation').iterdir():
    (VAL_CROPPED_PATH/dr.name).mkdir()
    for file in dr.iterdir():
        fn='validation_full\\'+file.name
        ima = open_image(PATH/fn)
        shape = ima.shape
        idx = np.where(np.array(validation_data.test_ds.fnames) == fn)[0][0]
        pred = validation_boxs[idx]
        cropped_ima = ima[int(shape[0]*pred[0]/sz):int(shape[0]*pred[2]/sz), int(shape[1]*pred[1]/sz):int(shape[1]*pred[3]/sz)]
        cv2.imwrite(str(VAL_CROPPED_PATH/dr.name/file.name), cv2.cvtColor((cropped_ima*255).astype(np.uint8), cv2.COLOR_RGB2BGR))

# %%
TEST_CROPPED_PATH = PATH/'test_cropperd'
#TEST_CROPPED_PATH.mkdir()
for file in (PATH/'test').iterdir():
    fn='test\\'+file.name
    ima = open_image(PATH/fn)
    shape = ima.shape
    idx = np.where(np.array(test_data.test_ds.fnames) == fn)[0][0]
    pred = test_boxs[idx]
    cropped_ima = ima[int(shape[0]*pred[0]/sz):int(shape[0]*pred[2]/sz), int(shape[1]*pred[1]/sz):int(shape[1]*pred[3]/sz)]
    cv2.imwrite(str(TEST_CROPPED_PATH/file.name), cv2.cvtColor((cropped_ima*255).astype(np.uint8), cv2.COLOR_RGB2BGR))
