# %%
from pathlib import Path
import json
import pandas as pd
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

from fastai.dataset import *

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
PATH = Path('D:/msc/kaggle_data/whales')

# %%
list(PATH.iterdir())
# Out:
# [WindowsPath('D:/msc/kaggle_data/whales/ft_vgg_model_best_weights.hdf5'),
#  WindowsPath('D:/msc/kaggle_data/whales/ft_vgg_model_weights.hdf5'),
#  WindowsPath('D:/msc/kaggle_data/whales/models'),
#  WindowsPath('D:/msc/kaggle_data/whales/sample_submission.csv'),
#  WindowsPath('D:/msc/kaggle_data/whales/some_whales_in_boxes.json'),
#  WindowsPath('D:/msc/kaggle_data/whales/test'),
#  WindowsPath('D:/msc/kaggle_data/whales/tmp'),
#  WindowsPath('D:/msc/kaggle_data/whales/train'),
#  WindowsPath('D:/msc/kaggle_data/whales/train.csv'),
#  WindowsPath('D:/msc/kaggle_data/whales/train_conv_layer_features.bc'),
#  WindowsPath('D:/msc/kaggle_data/whales/validation'),
#  WindowsPath('D:/msc/kaggle_data/whales/val_conv_layer_features.bc')]

# %% [markdown]
# # Get dataset to reasonable form

# %%
train = json.load((PATH/'some_whales_in_boxes.json').open())

# %%
train_df = pd.DataFrame(train)

# %%
train_df = train_df[['External ID', 'Label']]

# %%
train_df = train_df[train_df['Label'] != 'Skip']

# %%
train_df.iloc[0]['External ID']
# Out:
# '00ad9219.jpg'

# %%
train_df['Box'] = train_df.apply( lambda x: x['Label']['Tail'][0], axis=1)

# %%
def init2bb(l):
    return([min(l[0]['y'], l[1]['y'], l[2]['y'], l[3]['y']),
     min(l[0]['x'], l[1]['x'], l[2]['x'], l[3]['x']),
     max(l[0]['y'], l[1]['y'], l[2]['y'], l[3]['y']),
     max(l[0]['x'], l[1]['x'], l[2]['x'], l[3]['x'])])

# %%
train_df['BB'] = train_df.apply( lambda x: init2bb(x['Box']), axis=1)

# %%
train_df.head()
# Out:
#     External ID                                              Label  \
# 0  00ad9219.jpg  {'Tail': [[{'x': 10, 'y': 279}, {'x': 10, 'y':...
# 1  3b339885.jpg  {'Tail': [[{'x': 13, 'y': 498}, {'x': 13, 'y':...
# 2  00ded600.jpg  {'Tail': [[{'x': 1029, 'y': 472}, {'x': 1029, ...
# 3  06e622e0.jpg  {'Tail': [[{'x': 10, 'y': 262}, {'x': 10, 'y':...
# 4  3bf857ac.jpg  {'Tail': [[{'x': 2, 'y': 420}, {'x': 2, 'y': 1...
#
#                                                  Box                   BB
# 0  [{'x': 10, 'y': 279}, {'x': 10, 'y': 12}, {'x'...  [12, 10, 279, 1044]
# 1  [{'x': 13, 'y': 498}, {'x': 13, 'y': 66}, {'x'...  [66, 13, 498, 1034]
# 2  [{'x': 1029, 'y': 472}, {'x': 1029, 'y': 4}, {...   [4, 14, 472, 1029]
# 3  [{'x': 10, 'y': 262}, {'x': 10, 'y': 14}, {'x'...   [14, 10, 262, 880]
# 4  [{'x': 2, 'y': 420}, {'x': 2, 'y': 13}, {'x': ...   [13, 2, 420, 1044]

# %% [markdown]
# # Rewrite the fastai display functions and check that boxes make sense

# %%
IMG_PATH = PATH/'train'/'new_whale'

# %%
def show_img(im, figsize = None, ax = None):
    if not ax: fig, ax = plt.subplots(figsize = figsize)
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    return ax

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(linewidth=lw,foreground='black'), patheffects.Normal()])

# %%
def draw_rect(ax, b):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white',lw=2))
    draw_outline(patch,4)

# %%
def bb_hw(a): return np.array([a[1],a[0],a[3]-a[1]+1,a[2]-a[0]+1])

# %%
def draw_idx(i):
    ax = show_img(open_image(IMG_PATH/train_df.iloc[i]['External ID']))
    b = bb_hw(train_df.iloc[i]['BB'])
    draw_rect(ax, b)

# %%
draw_idx(18)

# %% [markdown]
# # Train a resnet of some sort

# %% [markdown]
# ## Make csv

# %%
csv_df = train_df[['External ID']]

# %%
csv_df.columns = ['fn']
# Out:
# Index(['fn'], dtype='object')

# %%
csv_df['bbox'] = train_df['BB'].apply(lambda x: ' '.join(str(p) for p in x))
# Out:
# C:\Users\msc12\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
csv_df.to_csv(PATH/'tmp/bb.csv', index=False)

# %% [markdown]
# ## Train a net

# %%
f_model=resnet34
sz=224
bs=64

# %%
tfm_y = TfmType.COORD
augs = [RandomFlip(tfm_y=tfm_y),
        RandomRotate(3, p=0.5, tfm_y=tfm_y),
        RandomLighting(0.1,0.1, tfm_y=tfm_y)]
tfms = tfms_from_model(f_model, sz, crop_type=CropType.NO, tfm_y=tfm_y, aug_tfms=augs)
md = ImageClassifierData.from_csv(PATH, IMG_PATH, PATH/'tmp/bb.csv', tfms = tfms, continuous = True, bs=bs)

# %%
idx = 2
fig, axes = plt.subplots(3,3, figsize = (9,9))
for i,ax in enumerate(axes.flat):
    x,y = next(iter(md.aug_dl))
    ima = md.val_ds.denorm(to_np(x))[idx]
    b = bb_hw(to_np(y[idx]))
    show_img(ima, ax=ax)
    draw_rect(ax,b)

# %% [markdown]
# # Crop the images
